# %% [markdown]
# <a href="https://colab.research.google.com/github/Elango420/data-science-dv-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
import yfinance as yf

# %% [markdown]
# pip install yfinance

# %%
usd_inr=yf.download('USDINR=X', start = '2004-0101',end= '2024-12-31',interval='1wk')
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['USDINR=X']: ValueError("time data '2004-0101' does not match format '%Y-%m-%d'")

# %% [markdown]
# usd_inr.head()

# %%
import yfinance as yf

# %%
usd_inr=yf.download('USDINR=X', start = '2004-0101',end= '2024-12-31',interval='1wk')
# Out:
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['USDINR=X']: ValueError("time data '2004-0101' does not match format '%Y-%m-%d'")

# %%
usd_inr.head()
# Out:
# Empty DataFrame
# Columns: [(Adj Close, USDINR=X), (Close, USDINR=X), (High, USDINR=X), (Low, USDINR=X), (Open, USDINR=X), (Volume, USDINR=X)]
# Index: []

# %%
usd_inr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 0 entries
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, USDINR=X)  0 non-null      float64
#  1   (Close, USDINR=X)      0 non-null      float64
#  2   (High, USDINR=X)       0 non-null      float64
#  3   (Low, USDINR=X)        0 non-null      float64
#  4   (Open, USDINR=X)       0 non-null      float64
#  5   (Volume, USDINR=X)     0 non-null      float64
# dtypes: float64(6)
# memory usage: 0.0 bytes

# %%
usd_inr.reset_index(inplace=True)

# %%
usd_inr.head()
# Out:
# Empty DataFrame
# Columns: [(Date, ), (Adj Close, USDINR=X), (Close, USDINR=X), (High, USDINR=X), (Low, USDINR=X), (Open, USDINR=X), (Volume, USDINR=X)]
# Index: []

# %% [markdown]
# usd_inr=usd_inr[['Date','Close']]
# usd_inr.columns=['Date','USDINR']

# %%
usd_inr.head()
# Out:
# Empty DataFrame
# Columns: [Date, USDINR]
# Index: []

# %%
import pandas as pd
import pandas as pd
from  google.colab import files
uploaded = files.upload()
gold_dataset=pd.read_csv("Gold vs USDINR.csv")
gold_dataset.head()
# Out:
#      <input type="file" id="files-cd60e66d-0545-4574-9237-ddee2e773d9d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd60e66d-0545-4574-9237-ddee2e773d9d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gold_dataset.head()
# Out:
#          Date    USD_INR     Goldrate
# 0  2024-01-01  83.240601  â¹5,066.31
# 1  2024-01-08  83.076103  â¹4,966.31
# 2  2024-01-15  83.160599  â¹5,015.33
# 3  2024-01-22  83.146103  â¹4,950.84
# 4  2024-01-29  82.927597  â¹4,976.77

# %% [markdown]
# gold_dataset['Goldrate']=gold_dataset['Goldrate'].replace('â','',regex=True).replace(',','',regex=True)

# %%
gold_dataset['Goldrate']=gold_dataset['Goldrate'].replace('â','',regex=True).replace(',','',regex=True).replace('¹','',regex=True)

# %%
gold_dataset.head()
# Out:
#          Date    USD_INR Goldrate
# 0  2024-01-01  83.240601  5066.31
# 1  2024-01-08  83.076103  4966.31
# 2  2024-01-15  83.160599  5015.33
# 3  2024-01-22  83.146103  4950.84
# 4  2024-01-29  82.927597  4976.77

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(gold_dataset)
plt.show()

# %%
import matplotlib.pyplot as plt
sns. boxplot (gold_dataset)
plt. show()

# %%
gold_dataset ['Goldrate'] = pd.to_numeric(gold_dataset['Goldrate'])
sns.regplot(x='USD_INR',y='Goldrate',data=gold_dataset)
# Out:
# <Axes: xlabel='USD_INR', ylabel='Goldrate'>

# %%
x=gold_dataset['USD_INR']
y=gold_dataset['Goldrate']

# %%
x
# Out:
# 0     83.240601
# 1     83.076103
# 2     83.160599
# 3     83.146103
# 4     82.927597
# 5     82.985298
# 6     83.009598
# 7     82.872299
# 8     82.910400
# 9     82.752296
# 10    82.965599
# 11    83.226601
# 12    83.392998
# 13    83.477798
# 14    83.349297
# 15    83.544998
# 16    83.301804
# 17    83.406303
# 18    83.459396
# 19    83.470100
# 20    83.286400
# 21    83.320900
# 22    83.473099
# 23    83.522102
# 24    83.601601
# 25    83.450897
# 26    83.493401
# 27    83.518501
# 28    83.674301
# 29    83.744400
# 30    83.743896
# 31    83.988998
# 32    83.948303
# 33    83.940598
# 34    83.895103
# 35    83.983597
# 36    83.934799
# 37    83.614700
# 38    83.617104
# 39    84.009399
# 40    83.945999
# 41    84.053802
# 42    84.081802
# 43    84.091499
# 44    84.306396
# 45    84.473801
# 46    84.488297
# 47    84.556999
# 48    84.666000
# 49    84.802002
# 50    84.945000
# 51    85.386002
# 52    85.786598
# Name: USD_INR, dtype: float64
